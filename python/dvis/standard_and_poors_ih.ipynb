# %%
import pandas as pd

df = pd.read_csv('datasets/SP500_01022020_12312024.csv')
df.dropna(inplace=True)
close = df.pop('SP500')
close.to_csv('datasets/SP500_01022020_12312024_Close.csv',index=False)
print(f'Minimum: {close.min()}\nMaximum: {close.max()}\nAverage: {close.mean()}')
# Out:
# Minimum: 2237.4
# Maximum: 6090.27
# Average: 4259.611263910971
